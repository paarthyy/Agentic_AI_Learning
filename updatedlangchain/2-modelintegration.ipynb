# %% [markdown]
# MODEL INTEGRATION WITH OPENAI, GOOGLE GEMINI AND GROQ

# %%
import os
from dotenv import load_dotenv
load_dotenv()

os.environ["OPENAI_API_KEY"] = os.getenv("OPENAI_API_KEY")
os.environ["GOOGLE_API_KEY"] = os.getenv("GOOGLE_API_KEY")
os.environ["GROQ_API_KEY"] = os.getenv("GROQ_API_KEY")
# Out:
# True

# %%
from langchain.chat_models import init_chat_model
model=init_chat_model("gpt-4.1")
model
# Out:
# ChatOpenAI(metadata={'lc_versions': {'langchain-core': '1.6.1', 'langchain': '1.3.18', 'langchain-openai': '1.6.0'}}, profile={'name': 'GPT-4.1', 'release_date': '2025-04-14', 'last_updated': '2025-04-14', 'open_weights': False, 'max_input_tokens': 1047576, 'max_output_tokens': 32768, 'text_inputs': True, 'image_inputs': True, 'audio_inputs': False, 'pdf_inputs': True, 'video_inputs': False, 'text_outputs': True, 'image_outputs': False, 'audio_outputs': False, 'video_outputs': False, 'reasoning_output': False, 'tool_calling': True, 'structured_output': True, 'attachment': True, 'temperature': True, 'image_url_inputs': True, 'pdf_tool_message': True, 'image_tool_message': True, 'tool_choice': True, 'tool_call_streaming': True}, client=<openai.resources.chat.completions.completions.Completions object at 0x00000237C5AF7110>, async_client=<openai.resources.chat.completions.completions.AsyncCompletions object at 0x00000237C64D5730>, root_client=<openai.OpenAI object at 0x00000237C5A71D90>
# ...

# %%
### invoke the model
response=model.invoke("Hello, how are you? ")
response.content

# %%
### how to call a google gemini model
from langchain.chat_models import init_chat_model

os.environ["GOOGLE_API_KEY"]=os.getenv("GOOGLE_API_KEY")
model=init_chat_model("google_genai:gemini-3.5-flash-lite")
response=model.invoke("why do parrots talk?")
response
# Out:
# AIMessage(content=[{'type': 'text', 'text': 'Parrots talk primarily because they are **social learners** and **vocal mimics**. In the wild, their survival and social structure depend on their ability to imitate sounds. \n\nHere is a breakdown of why and how parrots talk:\n\n### 1. Social Bonding and Flocking\nIn the wild, parrots live in large, noisy flocks. To stay connected, identify family members, and signal danger, they learn and share vocalizations. A parrot in your home views you and your family as its "flock." By mimicking human speech, the bird is trying to bond, communicate, and fit in with its social group.\n\n### 2. High Intelligence and Brain Structure\nParrots (along with corvids like crows and ravens, and songbirds) have remarkably large brains relative to their body size, particularly an area linked to vocal learning. Unlike most animals, which make instinctive sounds (like a dog barking or a cat meowing), parrots have to *learn* their vocalizations by listening to ot
# ...

# %%
model.invoke("write a paragraph about artificial intelligence")
# Out:
# AIMessage(content=[{'type': 'text', 'text': "Artificial Intelligence (AI) has rapidly evolved from the realm of science fiction into a transformative force reshaping modern society. At its core, AI involves the development of computer systems capable of performing tasks that typically require human intelligence, such as learning, reasoning, problem-solving, perception, and language understanding. By processing vast amounts of data at unprecedented speeds through machine learning and neural networks, AI algorithms can identify complex patterns and make autonomous decisions. Today, its applications are ubiquitous, driving innovations in healthcare through early disease detection, revolutionizing global commerce with personalized recommendations, and powering autonomous vehicles. As AI continues to advance, it holds the immense potential to solve some of humanity's most pressing challenges, while simultaneously sparking important ethical debates surrounding privacy, employment displacem
# ...

# %%
for chunk in model.stream("write a paragraph about artificial intelligence"):
    print(chunk.text,end="|",flush=True)
# Out:
# Artificial intelligence| (AI) has rapidly evolved from a theoretical concept in science fiction into a transformative force reshaping| modern society. At its core, AI refers to the simulation of human intelligence in machines designed to think, learn, adapt|, and problem-solve like humans. By processing vast amounts of data at unprecedented speeds, machine learning algorithms and neural networks can recognize| complex patterns, make autonomous decisions, and continuously improve their own performance without explicit reprogramming. Today, AI permeates nearly every aspect| of our lives—from the recommendation algorithms that curate our entertainment and the virtual assistants in our smartphones to groundbreaking advancements in medical| diagnostics, climate modeling, and autonomous transportation. As this powerful technology continues to advance, it holds the immense potential to solve some of humanity|'s greatest challenges, while simultaneously raising critical ethical questions reg
# ...

# %%
### ChatOpenAI

from langchain_openai import ChatOpenAI

model = ChatOpenAI(model="gpt-4.1")
response = model.invoke("Hello How are you?")
response

# %%
import os
from langchain_google_genai import ChatGoogleGenerativeAI


model = ChatGoogleGenerativeAI(model="gemini-3.5-flash-lite")
response = model.invoke("Why do parrots talk?")
response
# Out:
# AIMessage(content=[{'type': 'text', 'text': 'Parrots talk primarily because they are **social learners** and **vocal mimics**. In the wild, their survival and social structure depend heavily on their ability to imitate sounds. \n\nHere is a breakdown of why and how parrots talk:\n\n### 1. Social Bonding and Flocking\nIn the wild, parrots live in large, noisy flocks. To fit in, find a mate, and stay connected with their family group, they need to learn the specific "dialect" of their flock. They use mimicry to bond with others and reinforce social ties.\n\n### 2. Brain Structure (The Vocal Learning Center)\nParrots are part of a rare group of animals known as **vocal learners**. Unlike most animals, which are born with a fixed set of sounds, vocal learners can hear a sound and figure out how to replicate it using their vocal tract. \n* **The Syrinx:** Unlike humans, who use vocal cords in the larynx, birds use an organ called the **syrinx**, located at the base of the trachea. \n* **B
# ...

# %%
import os
from langchain.chat_models import init_chat_model

os.environ["GROQ_API_KEY"] = os.getenv("GROQ_API_KEY")

model = init_chat_model("groq:llama-3.3-70b-versatile")
response = model.invoke("Why do parrots talk?")
response
